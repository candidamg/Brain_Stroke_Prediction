# %% [markdown]
# # Brain Stroke Predictions

# %% [markdown]
# On this project we analyze brain stroke data to ...

# %% [markdown]
# ### Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read .csv file
df = pd.read_csv("Resources/clean_data.csv")
df.head()
# Out:
#    id  gender   age  hypertension  heart_disease  ever_married      work_type  \
# 0   0       1  67.0             0              1             1        Private
# 1   1       1  80.0             0              1             1        Private
# 2   2       0  49.0             0              0             1        Private
# 3   3       0  79.0             1              0             1  Self-employed
# 4   4       1  81.0             0              0             1        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
df.drop(columns=["id"], inplace= True)

# %% [markdown]
# ### Compile, Train and Evaluate our model

# %%
numeric= pd.get_dummies(df)
numeric
# Out:
#       gender   age  hypertension  heart_disease  ever_married  \
# 0          1  67.0             0              1             1
# 1          1  80.0             0              1             1
# 2          0  49.0             0              0             1
# 3          0  79.0             1              0             1
# 4          1  81.0             0              0             1
# ...      ...   ...           ...            ...           ...
# 4976       1  41.0             0              0             0
# 4977       1  40.0             0              0             1
# 4978       0  45.0             1              0             1
# 4979       1  40.0             0              0             1
# 4980       0  80.0             1              0             1
#
#       avg_glucose_level   bmi  stroke  work_type_Govt_job  work_type_Private  \
# 0                228.69  36.6       1                   0                  1
# 1                105.92  32.5       1                   0                  1
# 2                171.23  34.4       1                   0                  1
# 3                174.12  24.0       1                   0                  0
# 4                186.21  29.0       1                   0                  1
# ...                 ...   ...     ...                 ...                ...
# 4976              70.15  29.8       0                   0                  1
# 4977             191.15  31.1       0                   0                  1
# 4978              95.02  31.8       0                   1                  0
# 4979              83.94  30.0       0                   0                  1
# 4980              83.75  29.1       0                   0                  1
#
#       work_type_Self-employed  work_type_children  Residence_type_Rural  \
# 0                           0                   0                     0
# 1                           0                   0                     1
# 2                           0                   0                     0
# 3                           1                   0                     1
# 4                           0                   0                     0
# ...                       ...                 ...                   ...
# 4976                        0                   0                     1
# 4977                        0                   0                     0
# 4978                        0                   0                     1
# 4979                        0                   0                     1
# 4980                        0                   0                     0
#
#       Residence_type_Urban  smoking_status_Unknown  \
# 0                        1                       0
# 1                        0                       0
# 2                        1                       0
# 3                        0                       0
# 4                        1                       0
# ...                    ...                     ...
# 4976                     0                       0
# 4977                     1                       0
# 4978                     0                       0
# 4979                     0                       0
# 4980                     1                       0
#
#       smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                                  1                            0
# 1                                  0                            1
# 2                                  0                            0
# 3                                  0                            1
# 4                                  1                            0
# ...                              ...                          ...
# 4976                               1                            0
# 4977                               0                            0
# 4978                               0                            0
# 4979                               0                            0
# 4980                               0                            1
#
#       smoking_status_smokes
# 0                         0
# 1                         0
# 2                         1
# 3                         0
# 4                         0
# ...                     ...
# 4976                      0
# 4977                      1
# 4978                      1
# 4979                      1
# 4980                      0
#
# [4981 rows x 18 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = numeric.drop(["stroke"], axis=1).values
y = numeric["stroke"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  30
hidden_nodes_layer2 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                540
#
#  dense_1 (Dense)             (None, 10)                310
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 861
# Trainable params: 861
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 117/117 [==============================] - 2s 2ms/step - loss: 0.3283 - accuracy: 0.9333
# Epoch 2/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1834 - accuracy: 0.9521
# Epoch 3/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1663 - accuracy: 0.9521
# Epoch 4/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1591 - accuracy: 0.9521
# Epoch 5/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1557 - accuracy: 0.9521
# Epoch 6/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1531 - accuracy: 0.9521
# Epoch 7/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1512 - accuracy: 0.9521
# Epoch 8/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1496 - accuracy: 0.9521
# Epoch 9/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1483 - accuracy: 0.9521
# Epoch 10/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1472 - accuracy: 0.9521
# Epoch 11/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9521
# Epoch 12/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1455 - accuracy: 0.9521
# Epoch 13/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1450 - accuracy: 0.9521
# Epoch 14/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1444 - accuracy: 0.9521
# Epoch 15/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1439 - accuracy: 0.9521
# Epoch 16/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1436 - accuracy: 0.9521
# Epoch 17/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1428 - accuracy: 0.9521
# Epoch 18/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1424 - accuracy: 0.9521
# Epoch 19/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1414 - accuracy: 0.9521
# Epoch 20/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1411 - accuracy: 0.9521
# Epoch 21/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1413 - accuracy: 0.9518
# Epoch 22/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1407 - accuracy: 0.9521
# Epoch 23/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1397 - accuracy: 0.9523
# Epoch 24/100
# 117/117 [==============================] - 0s 3ms/step - loss: 0.1396 - accuracy: 0.9518
# Epoch 25/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1395 - accuracy: 0.9526
# Epoch 26/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1381 - accuracy: 0.9523
# Epoch 27/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1377 - accuracy: 0.9523
# Epoch 28/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1372 - accuracy: 0.9529
# Epoch 29/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1369 - accuracy: 0.9529
# Epoch 30/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1365 - accuracy: 0.9529
# Epoch 31/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9526
# Epoch 32/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1355 - accuracy: 0.9531
# Epoch 33/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1357 - accuracy: 0.9529
# Epoch 34/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1345 - accuracy: 0.9526
# Epoch 35/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1336 - accuracy: 0.9531
# Epoch 36/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1338 - accuracy: 0.9531
# Epoch 37/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1332 - accuracy: 0.9534
# Epoch 38/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1329 - accuracy: 0.9537
# Epoch 39/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1323 - accuracy: 0.9529
# Epoch 40/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1318 - accuracy: 0.9531
# Epoch 41/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1314 - accuracy: 0.9534
# Epoch 42/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1309 - accuracy: 0.9537
# Epoch 43/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1301 - accuracy: 0.9542
# Epoch 44/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1300 - accuracy: 0.9545
# Epoch 45/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1289 - accuracy: 0.9548
# Epoch 46/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1286 - accuracy: 0.9545
# Epoch 47/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1285 - accuracy: 0.9548
# Epoch 48/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1272 - accuracy: 0.9539
# Epoch 49/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1274 - accuracy: 0.9542
# Epoch 50/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1262 - accuracy: 0.9550
# Epoch 51/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1261 - accuracy: 0.9539
# Epoch 52/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1259 - accuracy: 0.9539
# Epoch 53/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1252 - accuracy: 0.9550
# Epoch 54/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1248 - accuracy: 0.9542
# Epoch 55/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1245 - accuracy: 0.9550
# Epoch 56/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1236 - accuracy: 0.9545
# Epoch 57/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1231 - accuracy: 0.9548
# Epoch 58/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1238 - accuracy: 0.9545
# Epoch 59/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1228 - accuracy: 0.9545
# Epoch 60/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1224 - accuracy: 0.9545
# Epoch 61/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1222 - accuracy: 0.9556
# Epoch 62/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1212 - accuracy: 0.9556
# Epoch 63/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1211 - accuracy: 0.9553
# Epoch 64/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1214 - accuracy: 0.9556
# Epoch 65/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1198 - accuracy: 0.9556
# Epoch 66/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1183 - accuracy: 0.9561
# Epoch 67/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1201 - accuracy: 0.9558
# Epoch 68/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1193 - accuracy: 0.9556
# Epoch 69/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1183 - accuracy: 0.9561
# Epoch 70/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1184 - accuracy: 0.9561
# Epoch 71/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1174 - accuracy: 0.9564
# Epoch 72/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1176 - accuracy: 0.9569
# Epoch 73/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1175 - accuracy: 0.9550
# Epoch 74/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1167 - accuracy: 0.9566
# Epoch 75/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1165 - accuracy: 0.9569
# Epoch 76/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1162 - accuracy: 0.9577
# Epoch 77/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1155 - accuracy: 0.9574
# Epoch 78/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1158 - accuracy: 0.9566
# Epoch 79/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1158 - accuracy: 0.9569
# Epoch 80/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9566
# Epoch 81/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9574
# Epoch 82/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1144 - accuracy: 0.9572
# Epoch 83/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1138 - accuracy: 0.9566
# Epoch 84/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1136 - accuracy: 0.9558
# Epoch 85/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1130 - accuracy: 0.9582
# Epoch 86/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1126 - accuracy: 0.9585
# Epoch 87/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1129 - accuracy: 0.9582
# Epoch 88/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1125 - accuracy: 0.9593
# Epoch 89/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1123 - accuracy: 0.9582
# Epoch 90/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1111 - accuracy: 0.9577
# Epoch 91/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1114 - accuracy: 0.9580
# Epoch 92/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 0.9585
# Epoch 93/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1110 - accuracy: 0.9580
# Epoch 94/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1102 - accuracy: 0.9574
# Epoch 95/100
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1103 - accuracy: 0.9593
# Epoch 96/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1099 - accuracy: 0.9596
# Epoch 97/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1097 - accuracy: 0.9577
# Epoch 98/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1084 - accuracy: 0.9593
# Epoch 99/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1094 - accuracy: 0.9590
# Epoch 100/100
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1085 - accuracy: 0.9577

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 39/39 - 0s - loss: 0.2367 - accuracy: 0.9374 - 216ms/epoch - 6ms/step
# Loss: 0.23672698438167572, Accuracy: 0.937399685382843

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 10
hidden_nodes_layer2 = 8
hidden_nodes_layer3 = 6

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                180
#
#  dense_4 (Dense)             (None, 8)                 88
#
#  dense_5 (Dense)             (None, 6)                 54
#
#  dense_6 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 329
# Trainable params: 329
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train, epochs=30)
# Out:
# Epoch 1/30
# 117/117 [==============================] - 1s 2ms/step - loss: 0.4471 - accuracy: 0.8624
# Epoch 2/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.2040 - accuracy: 0.9518
# Epoch 3/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1777 - accuracy: 0.9521
# Epoch 4/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1698 - accuracy: 0.9521
# Epoch 5/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1659 - accuracy: 0.9521
# Epoch 6/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1633 - accuracy: 0.9521
# Epoch 7/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1615 - accuracy: 0.9521
# Epoch 8/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1601 - accuracy: 0.9521
# Epoch 9/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1587 - accuracy: 0.9521
# Epoch 10/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1574 - accuracy: 0.9521
# Epoch 11/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1563 - accuracy: 0.9521
# Epoch 12/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1554 - accuracy: 0.9521
# Epoch 13/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1547 - accuracy: 0.9521
# Epoch 14/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1539 - accuracy: 0.9521
# Epoch 15/30
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1531 - accuracy: 0.9521
# Epoch 16/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1527 - accuracy: 0.9521
# Epoch 17/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.9521
# Epoch 18/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1515 - accuracy: 0.9521
# Epoch 19/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1509 - accuracy: 0.9521
# Epoch 20/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1505 - accuracy: 0.9521
# Epoch 21/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1499 - accuracy: 0.9521
# Epoch 22/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1493 - accuracy: 0.9521
# Epoch 23/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9521
# Epoch 24/30
# 117/117 [==============================] - 0s 1ms/step - loss: 0.1483 - accuracy: 0.9521
# Epoch 25/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1479 - accuracy: 0.9521
# Epoch 26/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1473 - accuracy: 0.9521
# Epoch 27/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1470 - accuracy: 0.9521
# Epoch 28/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9521
# Epoch 29/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1464 - accuracy: 0.9521
# Epoch 30/30
# 117/117 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9523

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 39/39 - 0s - loss: 0.1845 - accuracy: 0.9446 - 205ms/epoch - 5ms/step
# Loss: 0.1845296323299408, Accuracy: 0.944622814655304
